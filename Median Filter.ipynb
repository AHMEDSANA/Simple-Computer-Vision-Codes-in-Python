# %%
# Median_Filter
from PIL import Image, ImageFilter
# Opening the image
# (R prefixed to string in order to deal with '\' in paths)
image =cv2.imread(r'C:\Users\sanau\Desktop\GitHub\598152.jpg')
median = cv2.medianBlur(image,5)
plt.figure()
f, plots = plt.subplots(2, 1)
plots[0].imshow(image)
plots[1].imshow(median)
